# %% [markdown]
# # 01 Data and Sampling Check
#
# Verify Charades-STA annotations, video availability, and snippet sampling before running model code.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT / "src"))

from data_utils import load_video_lengths, load_sta_annotations, project_paths
from retrieval import sample_video_snippets

paths = project_paths(PROJECT_ROOT)
lengths = load_video_lengths(paths["test_csv"])
samples = load_sta_annotations(paths["sta_test"], paths["video_dir"], lengths)

summary = {
    "num_queries": len(samples),
    "num_unique_videos": len({sample.video_id for sample in samples}),
    "num_existing_videos": sum(sample.video_path.exists() for sample in samples),
    "first_sample": samples[0],
}
summary

# %%
sample = samples[0]
times, snippets, duration = sample_video_snippets(sample.video_path, num_snippets=8, snippet_frames=1)
frames = [snippet[0] for snippet in snippets]

sample.query, (sample.start, sample.end), duration, times

# %%
frames[0]

# %%
frames[-1]
